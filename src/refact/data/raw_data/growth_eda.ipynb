# %%
import pandas as pd

for 
growth_df = pd.read_csv("../raw_data/TOMATO_HARVEST_ENV_20231123.csv")

unique_count = growth_df.iloc[:, 2].nunique()
print(f"Column '{growth_df.columns[2]}'의 고유값 수: {unique_count}")
growth_df["YIELD_CNT"].value_counts()
# Out:
# Column 'YIELD_CNT'의 고유값 수: 7
# YIELD_CNT
# 3.20    2304
# 2.18    2016
# 2.44    2016
# 1.85    2016
# 1.84    2016
# 1.36    1440
# 2.98    1152
# Name: count, dtype: int64

# %%
import os 

for f in os.listdir("./"):
    if f[-3:] != "csv" or f == "TOMATO_GROWTH_LENGTH_ENV_20231123.csv":
        continue
    
    growth_df = pd.read_csv(f)

    unique_count = growth_df.iloc[:, 2].nunique()
    col = growth_df.columns[2]
    print(f"Column '{col}'의 고유값 수: {unique_count}")
    print(growth_df[col].value_counts().T)
    del growth_df
# Out:
# Column 'LEAF_CNT'의 고유값 수: 52
# LEAF_CNT
# 17.28    4032
# 12.32    3168
# 12.70    2304
# 12.63    2304
# 12.14    2016
# 14.21    2016
# 14.32    2016
# 15.25    2016
# 13.38    2016
# 11.84    2016
# 10.72    2016
# 16.14    2016
# 16.56    1728
# 17.16    1728
# 15.18    1728
# 13.85    1728
# 11.56    1605
# 13.91    1440
# 14.62    1440
# 16.53    1440
# 15.17    1440
# 15.95    1440
# 11.29    1440
# 16.01    1440
# 16.15    1152
# 15.03    1152
# 17.26    1152
# 16.43    1152
# 12.89    1152
# 15.35    1152
# 17.73    1152
# 15.75    1152
# 12.65     864
# 13.55     864
# 15.13     864
# 16.42     864
# 14.51     864
# 17.39     864
# 16.35     864
# 15.76     864
# 15.56     864
# 15.82     864
# 16.61     576
# 14.95     576
# 14.20     576
# 14.84     576
# 15.84     576
# 12.91     576
# 15.37     576
# 17.01     576
# 15.98     576
# 16.51     288
# Name: count, dtype: int64
# Column 'FRT_LNGTH'의 고유값 수: 47
# FRT_LNGTH
# 63.71    3456
# 62.25    2016
# 65.98    2016
# ...
