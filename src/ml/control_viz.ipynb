# %%
import pandas as pd
total_df = pd.read_csv("data/merged_fill.csv")

import json
with open("data/meta.json", "r") as f:
    meta = json.load(f)

# %% [markdown]
# 보조기기

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
plt.figure(figsize=(50, 5))

ax = sns.lineplot(x= range(total_df.shape[0]), y="SUB_MHRLS_OPRT_YN_1", data=total_df)
plt.show()

# %%
plt.figure(figsize=(50, 5))
ax = sns.lineplot(x= range(total_df.shape[0]), y="SUB_MHRLS_OPRT_YN_2", data=total_df)

# %%
plt.figure(figsize=(50, 5))
ax = sns.lineplot(x= range(total_df.shape[0]), y="SUB_MHRLS_OPRT_YN_3", data=total_df)

# %%
plt.figure(figsize=(10, 3))
ax = sns.lineplot(x= range(total_df.shape[0]), y="SUB_MHRLS_OPRT_YN_1", data=total_df)
ax = sns.lineplot(x= range(total_df.shape[0]), y="SUB_MHRLS_OPMD_1", data=total_df)

# %%
plt.figure(figsize=(10, 3))
ax = sns.lineplot(x= range(total_df.shape[0]), y="SUB_MHRLS_OPRT_YN_2", data=total_df)
ax = sns.lineplot(x= range(total_df.shape[0]), y="SUB_MHRLS_OPMD_2", data=total_df)

# %%
plt.figure(figsize=(10, 3))
ax = sns.lineplot(x= range(total_df.shape[0]), y="SUB_MHRLS_OPRT_YN_3", data=total_df)
ax = sns.lineplot(x= range(total_df.shape[0]), y="SUB_MHRLS_OPMD_3", data=total_df)

# %% [markdown]
# 수평스크린과 천장
#
# 작동여부와 개도율

# %%
plt.figure(figsize=(10, 3))
ax = sns.lineplot(x= range(total_df.shape[0]), y="HRZNT_SCRN_OPMD_1", data=total_df)
ax = sns.lineplot(x= range(total_df.shape[0]), y="HRZNT_SCRN_OPMD_2", data=total_df)

# %%
# 수평스크린작동모드_1 == 천창작동모드_1_좌
(total_df["HRZNT_SCRN_OPMD_1"] == total_df["SKLT_OPMD_1_LEFT"]).all()
# Out:
# True

# %%
plt.figure(figsize=(30, 3))

ax = sns.scatterplot(x= range(total_df.shape[0]), y="HRZNT_SCRN_OPDR_RATE_2", data=total_df)
ax = sns.scatterplot(x= range(total_df.shape[0]), y="HRZNT_SCRN_OPDR_RATE_1", data=total_df)

# %%
plt.figure(figsize=(30, 3))

# 오른쪽은 작동된 적이 없었음
# ax = sns.scatterplot(x= range(total_df.shape[0]), y="SKLT_OPDR_RATE_1_RIGHT", data=total_df)
ax = sns.scatterplot(x= range(total_df.shape[0]), y="SKLT_OPDR_RATE_1_LEFT", data=total_df)

# %% [markdown]
# 양액

# %%
plt.figure(figsize=(20, 3))

ax = sns.scatterplot(x= range(total_df.shape[0]), y="NTSLT_SPL_PH_LVL_STNG_VL", data=total_df)
ax = sns.scatterplot(x= range(total_df.shape[0]), y="NTSLT_SPL_ELCDT_STNG_VL", data=total_df)

# %% [markdown]
# 급수량

# %%
plt.figure(figsize=(20, 3))

ax = sns.scatterplot(x= range(total_df.shape[0]), y="WTSPL_QTY", data=total_df)

# %% [markdown]
# 공급온도

# %%
plt.figure(figsize=(20, 3))

ax = sns.scatterplot(x= range(total_df.shape[0]), y="SPL_TPRT_1", data=total_df)
ax = sns.scatterplot(x= range(total_df.shape[0]), y="SPL_TPRT_2", data=total_df)

# %% [markdown]
# 난방온도

# %%
plt.figure(figsize=(30, 3))

ax = sns.scatterplot(x= range(total_df.shape[0]), y="HTNG_TPRT_1", data=total_df)

# %% [markdown]
# 배기온도

# %%
plt.figure(figsize=(20, 3))

ax = sns.scatterplot(x= range(total_df.shape[0]), y="VNTILAT_TPRT_1", data=total_df)
ax = sns.scatterplot(x= range(total_df.shape[0]), y="VNTILAT_TPRT_2", data=total_df)

# %%
plt.figure(figsize=(20, 3))
ax = sns.scatterplot(x= range(total_df.shape[0]), y="VNTILAT_TPRT_3", data=total_df)
ax = sns.scatterplot(x= range(total_df.shape[0]), y="VNTILAT_TPRT_4", data=total_df)
ax = sns.scatterplot(x= range(total_df.shape[0]), y="VNTILAT_TPRT_5", data=total_df)

# %% [markdown]
# 이산화탄소
#
# 발생기 작동 여부와 설정값

# %%
plt.figure(figsize=(20, 3))

ax = sns.lineplot(x= range(total_df.shape[0]), y="CBDX_GNRT_OPRT_YN", data=total_df)

# %%
plt.figure(figsize=(20, 3))
ax = sns.scatterplot(x= range(total_df.shape[0]), y="CBDX_STNG_VL", data=total_df)

# %% [markdown]
# 훈증기
#
# 작동모드와 작동여부

# %%
plt.figure(figsize=(20, 3))

ax = sns.lineplot(x= range(total_df.shape[0]), y="FMGEQ_OPMD", data=total_df)

# %%
plt.figure(figsize=(20, 3))

ax = sns.lineplot(x= range(total_df.shape[0]), y="FMGEQ_OPRT_YN", data=total_df)

# %% [markdown]
# 순환펌프 작동여부

# %%
plt.figure(figsize=(20, 3))

ax = sns.lineplot(x= range(total_df.shape[0]), y="RTTN_PUMP_OPRT_YN_1", data=total_df)

# %%
plt.figure(figsize=(20, 3))

ax = sns.lineplot(x= range(total_df.shape[0]), y="RTTN_PUMP_OPRT_YN_2", data=total_df)

# %% [markdown]
# 분무 장치

# %%
plt.figure(figsize=(20, 3))

ax = sns.lineplot(x= range(total_df.shape[0]), y="SPRYN_DEVICE", data=total_df)

# %% [markdown]
# 3방밸브
#
# 작동모드와 개도율

# %%
plt.figure(figsize=(20, 3))

ax = sns.lineplot(x= range(total_df.shape[0]), y="TRWVLV_OPMD_1", data=total_df)

# %%
plt.figure(figsize=(20, 3))

ax = sns.lineplot(x= range(total_df.shape[0]), y="TRWVLV_OPMD_2", data=total_df)

# %%
plt.figure(figsize=(20, 3))
ax = sns.lineplot(x= range(total_df.shape[0]), y="TRWVLV_OPDR_RATE_1", data=total_df)

# %%
ax = sns.lineplot(x= range(total_df.shape[0]), y="TRWVLV_OPDR_RATE_2", data=total_df)
